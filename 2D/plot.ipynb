# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# import seaborn as sns
import os

# %%
csv_path = os.path.join('/home/anees.hashmi/Desktop/ML703/evaluation dataset/fbcampus_alpha_8_run_2_merged.csv')
# csv_path = os.path.join('/home/anees.hashmi/Desktop/ML703/evaluation dataset/intel_alpha_8_run_2_merged.csv')

# %%
len(df)
# Out:
# 2020

# %%
df = pd.read_csv(csv_path)
print(df.columns)
df.head()
# Out:
# Index(['noisy_motion_x', 'noisy_motion_y', 'noisy_motion_theta',
#        'noisy_motion_cov_xx', 'noisy_motion_cov_xy', 'noisy_motion_cov_xtheta',
#        'noisy_motion_cov_yy', 'noisy_motion_cov_ytheta',
#        'noisy_motion_cov_thetatheta', 'kalman_prediction_x',
#        'kalman_prediction_y', 'kalman_prediction_theta', 'lidar_x', 'lidar_y',
#        'lidar_theta', 'lidar_cov_xx', 'lidar_cov_xy', 'lidar_cov_xtheta',
#        'lidar_cov_yy', 'lidar_cov_ytheta', 'lidar_cov_thetatheta',
#        'ground_truth_x', 'ground_truth_y', 'ground_truth_theta', 'alpha',
#        'ekf_pos_x', 'ekf_pos_y', 'ekf_pos_theta', 'ukf_pos_x', 'ukf_pos_y',
#        'ukf_pos_theta'],
#       dtype='object')
#    noisy_motion_x  noisy_motion_y  noisy_motion_theta  noisy_motion_cov_xx  \
# 0    3.947141e-07   -4.038279e-07           -0.000004         2.117079e-10
# 1   -1.003149e-05    1.026401e-05            0.000102         2.101057e-10
# ...

# %%
# df.drop()

# %%
plt.figure(figsize=(20, 10))

# plt.plot(range(len(df)), df['ukf_pos_x'])
# plt.plot(range(len(df)), df['ukf_pos_y'])
# plt.plot(range(len(df)), df['ukf_pos_theta'])

# plt.plot(range(len(df)), df['lidar_x'])
plt.plot(range(len(df)), df['lidar_y'])


plt.plot(range(len(df)), df['ekf_pos_y'])

# plt.plot(range(len(df)), df['ground_truth_x'])
plt.plot(range(len(df)), df['ground_truth_y'])
# plt.plot(range(len(df)), df['ground_truth_theta'])

# plt.legend(['ukf_pos_y', 'lidar_y', 'ground_truth_y'])
# plt.legend(['ukf_pos_y', 'lidar_y', 'ekf_pos_y', 'ground_truth_y'])
plt.legend(['lidar_y', 'ekf_pos_y', 'ground_truth_y'])

# plt.legend(['ukf_pos_x', 'ukf_pos_y', 'ukf_pos_theta', 'ground_truth_x', 'ground_truth_y', 'ground_truth_theta'])
plt.show()

# %%
plt.figure(figsize=(20, 10))

# plt.plot(range(len(df)), df['ukf_pos_x'])
plt.plot(range(len(df)), df['ukf_pos_y'])
# plt.plot(range(len(df)), df['ukf_pos_theta'])

# plt.plot(range(len(df)), df['lidar_x'])
plt.plot(range(len(df)), df['lidar_y'])


# plt.plot(range(len(df)), df['ground_truth_x'])
plt.plot(range(len(df)), df['ground_truth_y'])
# plt.plot(range(len(df)), df['ground_truth_theta'])

plt.legend(['ukf_pos_y', 'lidar_y', 'ground_truth_y'])


# plt.legend(['ukf_pos_x', 'ukf_pos_y', 'ukf_pos_theta', 'ground_truth_x', 'ground_truth_y', 'ground_truth_theta'])
plt.show()
